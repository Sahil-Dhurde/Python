# %%
a={4,3,2,1}
print(a)
# Out:
# {1, 2, 3, 4}

# %%
b={'p','y','t','h','o','n'}
b.add((1,2,3))
print(b)
# Out:
# {'t', 'y', 'o', 'n', (1, 2, 3), 'h', 'p'}

# %%
c={20,60,30,72}
print(c)
# Out:
# {72, 20, 60, 30}

# %%
a={10,34,45,60}
print(a)
# Out:
# {10, 34, 45, 60}

# %%
a={10,34,45,60}
a.add(20)
print(a)
# Out:
# {34, 10, 45, 20, 60}

# %%
a={}
print(a)
# Out:
# {}

# %%
a=[]
print(a)
# Out:
# []

# %% [markdown]
# methods

# %%
a={1,2,3}
b={4,5,6,7}
a.add(9)
print(a)
# Out:
# {1, 2, 3, 9}

# %%
a={1,2,3}
b={}
a.clear()
print(a)
# Out:
# set()

# %%
a={1,2,3}
b={2,3}
a.difference(b)
print(a)
# Out:
# {1, 2, 3}

# %%
a={1,2,3}
b={2,3}
c={4,5}

a.discard(2)

# %%
a={1,2,3}
b={2,3}
a.intersection(b)
# Out:
# {2, 3}

# %%
a={1,2,3}
b={4,5,6,7}
a.pop()
print(a)
# Out:
# {2, 3}

# %%
a={1,2,3}
b={4,5,6,7}
a.remove(3)
print(a)
# Out:
# {1, 2}

# %%
a={1,2,3}
b={2,3}
c={4,5}
a.union(c)
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b={2,3}
c={4,5}
a.update(c)
print(a)
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b={2,3}
c={4,5}
a.symmetric_difference({2,3,4})
# Out:
# {1, 4}

# %%
a={1,2,3}
b={2,3}
c={4,5}
a.isdisjoint(b)
# Out:
# False

# %%
a={1,2,3}
b={2,3}
c={4,5}
b.issubset(a)
# Out:
# True

# %%
a={1,2,3}
b={2,3}
c={4,5}
a.issuperset(b)
# Out:
# True

# %%
a={8,9,16}
even=0
odd=0
for i in a:
      if i%2==0:
        even=even+1
      else:
        odd=odd+1
print(even)
print(odd)
# Out:
# 2
# 1

# %%
a=['a','p','p','l','e']
b=set(a)
print(list(b))
# Out:
# ['l', 'e', 'a', 'p']

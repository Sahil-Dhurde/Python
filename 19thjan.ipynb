# %%
a="ramesh"
b="j"+a[1:]
print(b)
# Out:
# jamesh

# %%
s='python'
b= s.upper()    
print(b)
# Out:
# PYTHON

# %%
s="PYTHON"
b=s.lower()
print(b)
# Out:
# python

# %%
input="my name is sahil"
c=input.capitalize()
print(c)
# Out:
# My name is sahil

# %%
input="my name is sahil"
c=input.title()
print(c)
# Out:
# My Name Is Sahil

# %%
a='Sahil'
b=a.swapcase()
print(b)
# Out:
# sAHIL

# %%
a='Data science in python'
b=a.startswith('Science')
c=a.endswith('Data')
print(b)
print(c)
# Out:
# False
# False

# %%
a='ramesh'
c=a.replace('r','j')
print(c)
# Out:
# jamesh

# %%
a='data science in python'
b=a.find('science')
print(b)
# Out:
# 5

# %%
a='data science in python'
c=a.index('java')
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 a='data science in python'
# ----> 2 c=a.index('java')
#       3 print(c)
#
# ValueError: substring not found

# %%
a='banana'
b=a.count('a')
print(b)
# Out:
# 3

# %%
a="ramesh"
b=a.islower()
print(b)
# Out:
# True

# %%
a="ramesh"
b=a.isalnum()
print(b)
# Out:
# True

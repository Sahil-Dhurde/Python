# %%
print("hello")
# Out:
# hello

# %%
a='apple'
for i in range(len(a)):
         if a[i] not in a[:i]:
            print(a[i],end='')
# Out:
# aple

# %%
vowel=0
c=0
b='education'
for i in b:
      if i in 'aeiou':
           vowel+=1
      else:
           c+=1
print(vowel)
print(c)
# Out:
# 5
# 4

# %%
a='abcdef'
for i in range(len(a)):
            if i%2==0:
                  print(a[i])
# Out:
# a
# c
# e

# %%
a='PyTHon'
upper=''
lowe=''
for i in range(len(a)):
      if a[i].isupper():
                 print('Uppercase: ', a[i])
                 upper+=a[i]
      else:
           print('Lowercase :' ,a[i])   
           lowe+=a[i]
print("Upper case :" ,upper)
print("Lower case: " ,lowe)
# Out:
# Uppercase:  P
# Lowercase : y
# Uppercase:  T
# Uppercase:  H
# Lowercase : o
# Lowercase : n
# Upper case : PTH
# Lower case:  yon

# %%
a='developer'
b=''
for i in a:
      if i=='a' or i=='i'or i=='o' or i=='e' or i=='u' :
           b+='*'
      else:
           b+=i
print(b)
# Out:
# d*v*l*p*r

# %%
a='Data Science and machine learning'
b=a.split(' ')
print(b)
c=print(len(b[0]))
d=print(len(b[1]))
e=print(len(b[2]))
f=print(len(b[3]))
g=print(len(b[4]))
longest=b[0]
for i in range(len(b)):
             if len(b[i])>len(longest):
                         longest=b[i]
print(longest)
# Out:
# ['Data', 'Science', 'and', 'machine', 'learning']
# 4
# 7
# 3
# 7
# 8
# learning

# %%
a='abc@gmail.com, adc@gmail.com, wxy@gmail.com'
b=a.split('@')
print(b)
print(b[0])
c=b[1].split(',')
print(c[1])
d=b[2].split(',')
print(d[1])
# Out:
# ['abc', 'gmail.com, adc', 'gmail.com, wxy', 'gmail.com']
# abc
#  adc
#  wxy

# %%
emails = input("Enter emails separated by comma: ")
email_list = emails.split(',')

print("Usernames are:")
for email in email_list:
    email = email.strip()          
    username = email.split('@')[0] 
    print(username)

# %%
print('valid\rSo')
# Out:
# Solid

# %%
print('Sahil\v Dhurde')
# Out:
# Sahil Dhurde

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
x=3
x+=x*2
x-=x//3
print(x)
# Out:
# 6

# %%
a=5
b=10
a+=b
b-=a
print(a,b)
# Out:
# 15 -5

# %%
x=2
x**=3
x//=4
print(x)
# Out:
# 2

# %%
x=7
x%=3
x+=4
print(x)
# Out:
# 5

# %%
x=5
y=x
x+=3
y*=2
print(x,y)
# Out:
# 8 10

# %%
a=20
a-=4
a//=2
print(a)
# Out:
# 8

# %%
a=30
b=10
a=b
b=a//b
print(a+b)
# Out:
# 11

# %%
a=60
b=30
a+=b
b+=a*b
print(a+b)
# Out:
# 2820

# %%
a=10
b=10
print(a==b)
print(a>b)
# Out:
# True
# False

# %%
x=5
y=7
print(x!=y)
# Out:
# True

# %%
a=15
b=20
c=15
print(a==c)
print(a>=b)
print(b>a)
# Out:
# True
# False
# True

# %%
x=3
y=3
z=5
print(x==y>z)
# Out:
# False

# %%
age=18
print(age>=18)
print(age>18)
# Out:
# True
# False

# %%
a=0
b=False
print(a==b)
print(a is b)
# Out:
# True
# False

# %%
print("I am sahil Dhurde ")
# Out:
# I am sahil Dhurde

# %%
fruit ='mango'
print(fruit[2]+fruit[3]+fruit[4])
# Out:
# ngo

# %%
fruit ='mango'
print(fruit[0:3])
# Out:
# man

# %%
a ='Telecommunication'
print(a[11:17]+a[0:4])
# Out:
# cationTele

# %%
a ='Telecommunication'
print(a[6:11]+a[11:13]+a[0:4])
# Out:
# mmunicaTele

# %%
a ='Telecommunication'
print(a[0:4]+a[11:17])
# Out:
# Telecation

# %%
b = 'Code'
print(b[2:4]+b[0:2])
# Out:
# deCo

# %%
b = 'Code'
print(b[1:3]+b[3]+b[0])
# Out:
# odeC

# %%
b = 'Code'
print(b[3]+b[0]+b[1:3])
# Out:
# eCod

# %%
b ='code'
print(b)
# Out:
# code

# %%
base = 10
height = 4
print("Area of TRaingle is:", 0.5 * base * height)
# Out:
# Area of TRaingle is: 20.0

# %%
redius = 2
print("Area of circle is :", 3.14*redius*redius)
print("Circumference of circle is :",2 * 3.14 * redius)
# Out:
# Area of circle is : 12.56
# Circumference of circle is : 12.56

# %%
side = 12
print("Area of square is :", side * side )
# Out:
# Area of square is : 144

# %%
base = 12
height =3
print("area of parallegram is :", base * height )
# Out:
# area of parallegram is : 36

# %%
var ='sahil'
sirname ='dhurde'
print("My name is",var,sirname)
# Out:
# My name is sahil dhurde

# %%
a ,b , c = 10 , 22
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 a ,b , c = 10 , 22
#       2 print(a,b,c)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
A =10/2
b =10//2
c=11/2
d=11//2
e =11%2
print(A)
print(b)
print(c)
print(d)
print(e)
# Out:
# 5.0
# 5
# 5.5
# 5
# 1

# %%
a = 342//10
print(a)
a= 342 %10
print(a)
# Out:
# 34
# 2

# %%
a = 571
b=a//10
print(b)
c = a % 10
print(c)
# Out:
# 57
# 1

# %%
a =input('Enter Your Namre:')
print(a)
# Out:
# sahil

# %%
a ,b = int(input('Enter Base :')), int(input('Enter Height :'))
# Area of triangle
c = 0.5 * a * b
print("Area of triangle is :", c)
# Out:
# Area of triangle is : 4.5

# %%
ip = input("Enter your Input: ")
print(ip[3:6]+ip[0:3])
# Out:
# prodox

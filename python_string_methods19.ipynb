# %%
s='python'
b= s.upper()
print(b)

# %%
s='python'
b= s.lower()
print(b)

# %%
url=input("Enter the url")
parts=url.splits("://")
protocol=parts.splits[0]
sub=parts.splits[1]

print(protocol)
print(sub)

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.copy())
# Out:
# {1: 'one', 2: 'two', 3: 'Three'}

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.items())
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'Three')])

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.keys())
# Out:
# dict_keys([1, 2, 3])

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.values())
# Out:
# dict_values(['one', 'two', 'Three'])

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.pop(1))
# Out:
# one

# %%
a={1:'one', 2:'two', 3:'Three'}
b=dict.fromkeys(a,'smd')
print(b)
# Out:
# {1: 'smd', 2: 'smd', 3: 'smd'}

# %%
a={1:'one', 2:'two', 3:'Three'}
print(a.clear())
# Out:
# None

# %% [markdown]
# Methods **bold text**

# %%
a=[1,2,3,4,3,2]
b=dict.fromkeys(a)
print(list(b))
# Out:
# [1, 2, 3, 4]

# %%
a={1:'one', 2:'two', 3:'Three'}
b={x for x in a.keys()}
c={x for x in a.values()}
d=dict(zip(c,b))
print(b)
print(c)
print(d)
# Out:
# {1, 2, 3}
# {'one', 'two', 'Three'}
# {'one': 1, 'two': 2, 'Three': 3}

# %%
a={1:'one', 2:'two', 3:'Three'}
b={x:y for y,x in a.items()}
print(b)
# Out:
# {'one': 1, 'two': 2, 'Three': 3}

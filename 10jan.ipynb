# %%
a ='doxpro'
print(a[1:4:2])
# Out:
# op

# %%
a ='doxpro'
print(a[1:4:1])
# Out:
# oxp

# %%
s='python'
print(s[1:4])
# Out:
# yth

# %%
s='programming'
print(s[-3:])
# Out:
# ing

# %%
s='developer'
print(s[::2])
# Out:
# dvlpr

# %%
s='abcdefghij'
print(s[1:8:2])
# Out:
# bdfh

# %%
s='12345'
n=int(s[1:4])
n+=10
print(n)
# Out:
# 244

# %%
s='0123456789'
print(s[1:-1:3])
# Out:
# 147

# %%
s='abcdefghijklm'
print(s[2:11:3])
# Out:
# cfi

# %%
s='programming'
a=len(s)//2
print(a)
# Out:
# 5

# %%
a='ramesh'
print(a[2:6:4])
# Out:
# m

# %%
a='dipak' 
print(a[::-1])
# Out:
# kapid

# %%
a='dipak' 
print(a[1:5:-1])

# %%
a='doxpro' 
print(a[-1:-4:-1])
# Out:
# orp

# %%
a='Doxpro Robotics'
print(a[-6:-9:-1])
print(a[-4:-7:-1])
print(a[-12:-15:-1])
# Out:
# boR
# tob
# pxo

# %%
a=int(input("Enter the Number"))
if a >= 0:
    print('You Enter a Positive Number ')
else:
    print("You enter a negative number")
# Out:
# You Enter a Positive Number

# %%
num = int(input('Enter a Number'))
if num%2==0 :
    print('Even Number')
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
a=10
b=16
c=13
if a>b and a>c:
    print('A is largest')
elif b>a and b>c:
    print('B the largest')
else:
    print('C is the largest')
# Out:
# B the largest

# %%
a='developer'
b = (a[6:9])
print(b)
if b =='per':
    print('Per is the detected')
else:
    print('not detected')
# Out:
# per
# Per is the detected

# %%
a='developer'
b='per'
if b in a :
    print("per is the detected ")
else:
    print("Not detected")
# Out:
# per is the detected

# %%
a =input("Enter the input")
print(a)
b =input("Enter a text to find")
if b in a:
    print("Is detected")
else:
    print("Is not detected")
# Out:
# sahil
# Is detected

# %%
a=input('Enter a alphabet')
if a=='a'or a=='e'or a=='i'or a=='o'or a=='u':
    print('you Enter a vowel')
else:
    print('You enter a consonant')
# Out:
# You enter a consonant

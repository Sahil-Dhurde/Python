# %%
a=[10,20,30,40]
sum=0
for i in range(len(a)):
              sum = sum + a[i]
print(sum)
# Out:
# 100

# %%
a=[10,20,30,40]
a.reverse()
print(a)
# Out:
# [40, 30, 20, 10]

# %%
a=[10,20,30,40]
b=[]
for i in range(len(a)-1,-1,-1):
              b.append(a[i])
print(b)
if a==b[::-1] :
       print("List is palindrome")
else :
       print("List is not palindrome")
# Out:
# [40, 30, 20, 10]
# List is palindrome

# %%
a=1,2,'abc'
print(a)
print(type(a))
# Out:
# (1, 2, 'abc')
# <class 'tuple'>

# %%
a=(1,2,'abc')
b=list(a)
print(a)
b[2]= 3
a=tuple(b)
print(a)
# Out:
# (1, 2, 'abc')
# (1, 2, 3)

# %%
a=(10,20,30,60,50)
b=list(a)
b.sort(reverse=True)
print(b)
a=tuple(b)
print(a)
# Out:
# [60, 50, 30, 20, 10]
# (60, 50, 30, 20, 10)

# %%
a=(15,23,32,64,55)
even=0
odd=0
for i in a:
          if i%2==0:
               even+=1
          else:
               odd+=1
print(even)
print(odd)
# Out:
# 2
# 3

# %%
a=[1,2,3,4]
b=a.copy()
print(b)
small=a[0]
for i in range(len(a)):
               for j in range(i+1,len(a)):
                            if a[i]>a[j]:
                                 a[i],a[j]=a[j],a[i]

print(a)
if a == b:
        print("sorted")
else:
        print("not sorted")
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# sorted

# %%
a=[1,2,3,4]
b=a.copy()
print(b)
small=a[0]
for i in range(len(a)):
               for j in range(i+1,len(a)):
                            if a[i]<a[j]:
                                 a[i],a[j]=a[j],a[i]

print(a)
if a == b:
        print("sorted")
else:
        print("not sorted")
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]
# not sorted

# %%
a=(1,23,34,3)
b=sum(a)
print(b)
# Out:
# 61

# %%
a=(1,23,34,3)
b=max(a)
print(b)
# Out:
# 34

# %%
a=(1,2,3,3)
del(a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1297832279.py in <cell line: 0>()
#       1 a=(1,2,3,3)
#       2 del(a)
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
a=[1,0,2,0,3,0]
b=[]
for i in a:
         if i!=0:
              b.append(i)

print(b)
# Out:
# [1, 2, 3]

# %%
a=[1,2,3,4,5,6]
b=[]
for i in a:
         if i<5:
             b.append(i)
print(b)
# Out:
# [1, 2, 3, 4]

# %%
a={1,1}
print(a)
# Out:
# {1}

# %%
a=1,2
print(a)
# Out:
# (1, 2)

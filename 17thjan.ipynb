# %%
i=5
while i>=1:
      j=1
      while j<=i:
            print(j,end='')
            j=j+1
      print()
      i=i-1
# Out:
# 12345
# 1234
# 123
# 12
# 1

# %%
a=90
big=0
while a>0:
      last=a%10
      if big<last:
          big=last
     
      a=a//10
      
print(big)
# Out:
# 9

# %%
a=102030
rev=0
while a>0:
      last=a%10
      if last==0:
           a=a//10
           continue
      else:
           rev =rev*10 + last
           a=a//10
print(rev)

s=0
while rev>0:
      endr=rev % 10
      s =s * 10 + endr
      rev = rev // 10
print(s)
# Out:
# 321
# 123

# %%
a=1231334
b=a
rev=0
while a>0:
      last=a%10
      if last==3:
           a=a//10
           continue
      else:
           rev =rev*10 + last
           a=a//10
print(rev)
sd=rev
s=0
while rev>0:
      endr=rev % 10
      s =s * 10 + endr
      rev = rev // 10
print(s)
if sd==s :
   print("string  is palindrome")
else:
   print("string is not palindrome")
# Out:
# 4121
# 1214
# string is not palindrome

# %%
i=1
while i<=5:
      j=1
      while j<=i:
            print(j,end='')
            j=j+1
      print()
      i=i+1
# Out:
# 1
# 12
# 123
# 1234
# 12345

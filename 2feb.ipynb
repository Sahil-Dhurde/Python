# %%
a=['a',2,'b',3,'c',4]
a[3:3]=[5]
print(a)
# Out:
# ['a', 2, 'b', 5, 3, 'c', 4]

# %%
a=['a',2,'b',3,'c',4]
a[3:3]=[5,6]
print(a)
# Out:
# ['a', 2, 'b', 5, 6, 3, 'c', 4]

# %%
a=['a',2,'b',3,'c',4]
a[6:6]=[7]
print(a)
# Out:
# ['a', 2, 'b', 3, 'c', 4, 7]

# %%
a=['a',2,'b',3,'c',4]
a.append('e')
print(a)
# Out:
# ['a', 2, 'b', 3, 'c', 4, 'e']

# %%
a=['a',2,'b',3,'c',4]
a.insert(1,4)
print(a)
# Out:
# ['a', 4, 2, 'b', 3, 'c', 4]

# %%
a=['a',2,'b',3,'c',4]
a.insert(1,[1,2,3])
print(a)
# Out:
# ['a', [1, 2, 3], 2, 'b', 3, 'c', 4]

# %%
a=[1,2,3,4,5]
a.extend([5,6,7,8])
print(a)
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8]

# %%
a=[4,5,6,7]
a.reverse()
print(a)
# Out:
# [7, 6, 5, 4]

# %%
a=[4,5,6,7]
a.sort()
print(a)
# Out:
# [4, 5, 6, 7]

# %%
a=[2,5,1,3,5]
a.sort(reverse=True)
print(a)
# Out:
# [5, 5, 3, 2, 1]

# %%
a=[20,16,4,12,20]
print(a.count(20))
# Out:
# 2

# %%
a=[20,16,4,12,20]
print(a.index(20))
# Out:
# 0

# %%
a=[20,16,4,12,20]
a.pop()
print(a)
# Out:
# [20, 16, 4, 12]

# %%
a=[20,16,4,12,20]
a.pop(3)
print(a)
# Out:
# [20, 16, 4, 20]

# %%
a=[20,16,4,12,20]
a.remove(16)
print(a)
# Out:
# [20, 4, 12, 20]

# %%
a=['ramesh','suresh','Ramesh','Naresh','Suresh']
b=[]
for i in a:
           x = i.upper()
           if x not in b:
                    b.append(x)
print(b)
# Out:
# ['RAMESH', 'SURESH', 'NARESH']

# %%
a=['ramesh','suresh','naresh','mangesh','om']
b=a[-2]
print(b)
a.insert(0,b)
a.pop(-2)
print(a)
# Out:
# mangesh
# ['mangesh', 'ramesh', 'suresh', 'naresh', 'om']

# %%
a=['abc','def','ghi','klm']
b=[]
for i in a:
        print(i.upper())
        b.append(i.upper())
print(b)
# Out:
# ABC
# DEF
# GHI
# KLM
# ['ABC', 'DEF', 'GHI', 'KLM']
